# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras import layers,models
from tensorflow.keras.utils import to_categorical
from tensorflow.keras import regularizers
from sklearn.utils import shuffle

# %%
iono_data=pd.read_csv('Downloads/ionosphere_data.csv')

# %%
iono_data.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1         0   0.99539  -0.05889   0.85243   0.02306   0.83398
# 1         1         0   1.00000  -0.18829   0.93035  -0.36156  -0.10868
# 2         1         0   1.00000  -0.03365   1.00000   0.00485   1.00000
# 3         1         0   1.00000  -0.45161   1.00000   1.00000   0.71216
# 4         1         0   1.00000  -0.02401   0.94140   0.06531   0.92106
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0  -0.37708   1.00000    0.03760  ...   -0.51171    0.41078   -0.46168
# 1  -0.93597   1.00000   -0.04549  ...   -0.26569   -0.20468   -0.18401
# 2  -0.12062   0.88965    0.01198  ...   -0.40220    0.58984   -0.22145
# 3  -1.00000   0.00000    0.00000  ...    0.90695    0.51613    1.00000
# 4  -0.23255   0.77152   -0.16399  ...   -0.65158    0.13290   -0.53206
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# ...

# %%
print(iono_data.shape)
print(iono_data.size)
# Out:
# (351, 35)
# 12285

# %%
iono_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
# ...

# %%
iono_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature2   351 non-null    int64
#  2   feature3   351 non-null    float64
#  3   feature4   351 non-null    float64
#  4   feature5   351 non-null    float64
#  5   feature6   351 non-null    float64
#  6   feature7   351 non-null    float64
#  7   feature8   351 non-null    float64
#  8   feature9   351 non-null    float64
#  9   feature10  351 non-null    float64
#  10  feature11  351 non-null    float64
#  11  feature12  351 non-null    float64
#  12  feature13  351 non-null    float64
#  13  feature14  351 non-null    float64
#  14  feature15  351 non-null    float64
#  15  feature16  351 non-null    float64
#  16  feature17  351 non-null    float64
#  17  feature18  351 non-null    float64
#  18  feature19  351 non-null    float64
# ...

# %%
iono_data.shape
# Out:
# (351, 35)

# %% [markdown]
# Shuffling data and removing irrelevant data

# %%
iono_data.isna().sum()
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %%
iono_data.isnull().sum()
# Out:
# feature1     0
# feature2     0
# feature3     0
# feature4     0
# feature5     0
# feature6     0
# feature7     0
# feature8     0
# feature9     0
# feature10    0
# feature11    0
# feature12    0
# feature13    0
# feature14    0
# feature15    0
# feature16    0
# feature17    0
# feature18    0
# feature19    0
# feature20    0
# feature21    0
# feature22    0
# feature23    0
# feature24    0
# feature25    0
# feature26    0
# feature27    0
# feature28    0
# feature29    0
# feature30    0
# feature31    0
# feature32    0
# feature33    0
# feature34    0
# label        0
# dtype: int64

# %% [markdown]
# splitting the data###

# %%
data = iono_data.iloc[:, :-1]
targets = iono_data.iloc[:,-1]

# %%
print(data.shape)
print(targets.shape)
# Out:
# (351, 34)
# (351,)

# %%
iono_data.columns
# Out:
# Index(['feature1', 'feature2', 'feature3', 'feature4', 'feature5', 'feature6',
#        'feature7', 'feature8', 'feature9', 'feature10', 'feature11',
#        'feature12', 'feature13', 'feature14', 'feature15', 'feature16',
#        'feature17', 'feature18', 'feature19', 'feature20', 'feature21',
#        'feature22', 'feature23', 'feature24', 'feature25', 'feature26',
#        'feature27', 'feature28', 'feature29', 'feature30', 'feature31',
#        'feature32', 'feature33', 'feature34', 'label'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
labelencoder = LabelEncoder()
iono_data['feature1']=labelencoder.fit_transform(iono_data['feature1'])
iono_data['feature2']=labelencoder.fit_transform(iono_data['feature2'])
iono_data['feature3']=labelencoder.fit_transform(iono_data['feature3'])
iono_data['feature4']=labelencoder.fit_transform(iono_data['feature4'])
iono_data['feature5']=labelencoder.fit_transform(iono_data['feature5'])
iono_data['feature6']=labelencoder.fit_transform(iono_data['feature6'])
iono_data['feature7']=labelencoder.fit_transform(iono_data['feature7'])
iono_data['feature8']=labelencoder.fit_transform(iono_data['feature8'])
iono_data['feature9']=labelencoder.fit_transform(iono_data['feature9'])
iono_data['feature10']=labelencoder.fit_transform(iono_data['feature10'])
iono_data['feature11']=labelencoder.fit_transform(iono_data['feature11'])
iono_data['feature12']=labelencoder.fit_transform(iono_data['feature12'])
iono_data['feature13']=labelencoder.fit_transform(iono_data['feature13'])
iono_data['feature14']=labelencoder.fit_transform(iono_data['feature14'])
iono_data['feature15']=labelencoder.fit_transform(iono_data['feature15'])
iono_data['feature16']=labelencoder.fit_transform(iono_data['feature16'])
iono_data['feature17']=labelencoder.fit_transform(iono_data['feature17'])
iono_data['feature18']=labelencoder.fit_transform(iono_data['feature18'])
iono_data['feature19']=labelencoder.fit_transform(iono_data['feature19'])
iono_data['feature20']=labelencoder.fit_transform(iono_data['feature20'])
iono_data['feature21']=labelencoder.fit_transform(iono_data['feature21'])
iono_data['feature22']=labelencoder.fit_transform(iono_data['feature22'])
iono_data['feature23']=labelencoder.fit_transform(iono_data['feature23'])
iono_data['feature24']=labelencoder.fit_transform(iono_data['feature24'])
iono_data['feature25']=labelencoder.fit_transform(iono_data['feature25'])
iono_data['feature26']=labelencoder.fit_transform(iono_data['feature26'])
iono_data['feature27']=labelencoder.fit_transform(iono_data['feature27'])
iono_data['feature28']=labelencoder.fit_transform(iono_data['feature28'])
iono_data['feature29']=labelencoder.fit_transform(iono_data['feature29'])
iono_data['feature30']=labelencoder.fit_transform(iono_data['feature30'])
iono_data['feature31']=labelencoder.fit_transform(iono_data['feature31'])
iono_data['feature32']=labelencoder.fit_transform(iono_data['feature32'])
iono_data['feature33']=labelencoder.fit_transform(iono_data['feature33'])
iono_data['feature34']=labelencoder.fit_transform(iono_data['feature34'])
iono_data['label']=labelencoder.fit_transform(iono_data['label'])

# %%
iono_data.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1         0       215        65       137       109       158
# 1         1         0       218        28       164         7        10
# 2         1         0       218        76       203        89       230
# 3         1         0       218        13       203       258       119
# 4         1         0       218        84       172       133       192
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0        18       243        129  ...         37         97         47
# 1         3       243         70  ...         69         25         75
# 2        43       194        108  ...         51        141         69
# 3         0        30         96  ...        269        122        280
# 4        26       152         25  ...         24         59         35
#
#    feature29  feature30  feature31  feature32  feature33  feature34  label
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data, train_targets, test_targets = train_test_split(data, targets, test_size=0.3)

# %%
train_data, validation_data, train_targets, validation_targets = train_test_split(train_data, train_targets, test_size=.2)

# %% [markdown]
# standardizing the variables###

# %%
mean = np.mean(train_data)
std = np.std(train_data)


train_data -= mean
train_data /= std

validation_data -= mean
validation_data /= std

test_data -= mean
test_data /= std

# %%
from keras import models, layers

# %%
model = models.Sequential()
model.add(layers.Dense(16, input_shape=(train_data.shape[1],), activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(train_data, train_targets, epochs=100, validation_data=(validation_data, validation_targets))
# Out:
# Epoch 1/100
# 7/7 [==============================] - 1s 64ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 2/100
# 7/7 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 3/100
# 7/7 [==============================] - 0s 13ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 4/100
# 7/7 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 5/100
# 7/7 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 6/100
# 7/7 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.0000e+00 - val_loss: nan - val_accuracy: 0.0000e+00
# Epoch 7/100
# ...

# %%
# Standardizing the amount column
from sklearn import preprocessing
scaler = preprocessing.StandardScaler()
#standard scaling
iono_data['label'] = scaler.fit_transform(iono_data["label"].values.reshape (-1,1))

#removing label
df = iono_data.drop("label", axis=1)

# %%
cols = iono_data.columns.tolist()
cols = [c for c in cols if c not in ["label"]]
target =("feature2")

# %%
iono_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 351 entries, 0 to 350
# Data columns (total 35 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   feature1   351 non-null    int64
#  1   feature2   351 non-null    float64
#  2   feature3   351 non-null    int64
#  3   feature4   351 non-null    int64
#  4   feature5   351 non-null    int64
#  5   feature6   351 non-null    int64
#  6   feature7   351 non-null    int64
#  7   feature8   351 non-null    int64
#  8   feature9   351 non-null    int64
#  9   feature10  351 non-null    int64
#  10  feature11  351 non-null    int64
#  11  feature12  351 non-null    int64
#  12  feature13  351 non-null    int64
#  13  feature14  351 non-null    int64
#  14  feature15  351 non-null    int64
#  15  feature16  351 non-null    int64
#  16  feature17  351 non-null    int64
#  17  feature18  351 non-null    int64
#  18  feature19  351 non-null    int64
#  19  feature20  351 non-null    int64
# ...

# %% [markdown]
# encoding features###

# %%
iono_data.feature2=iono_data.feature2.mask(iono_data.feature2==0).fillna(2)

# %%
iono_data.label=iono_data.label.mask(iono_data.label==0).fillna(0.5)

# %%
iono_data.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0         1       2.0       215        65       137       109       158
# 1         1       2.0       218        28       164         7        10
# 2         1       2.0       218        76       203        89       230
# 3         1       2.0       218        13       203       258       119
# 4         1       2.0       218        84       172       133       192
#
#    feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# 0        18       243        129  ...         37         97         47
# 1         3       243         70  ...         69         25         75
# 2        43       194        108  ...         51        141         69
# 3         0        30         96  ...        269        122        280
# 4        26       152         25  ...         24         59         35
#
#    feature29  feature30  feature31  feature32  feature33  feature34     label
# ...

# %%
y=iono_data['label']

# %%
y
# Out:
# 0      0.748331
# 1     -1.336306
# 2      0.748331
# 3     -1.336306
# 4      0.748331
#          ...
# 346    0.748331
# 347    0.748331
# 348    0.748331
# 349    0.748331
# 350    0.748331
# Name: label, Length: 351, dtype: float64

# %%
x=iono_data

# %%
x
# Out:
#      feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0           1       2.0       215        65       137       109       158
# 1           1       2.0       218        28       164         7        10
# 2           1       2.0       218        76       203        89       230
# 3           1       2.0       218        13       203       258       119
# 4           1       2.0       218        84       172       133       192
# ..        ...       ...       ...       ...       ...       ...       ...
# 346         1       2.0       118       161       103        23       162
# 347         1       2.0       191       106       179        63       197
# 348         1       2.0       190       103       166        60       206
# 349         1       2.0       162        87       193        70       207
# 350         1       2.0       124       187       102        48       177
#
#      feature8  feature9  feature10  ...  feature26  feature27  feature28  \
# ...

# %%
x=iono_data.drop(columns='label')

# %%
x
# Out:
#      feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 0           1       2.0       215        65       137       109       158
# 1           1       2.0       218        28       164         7        10
# 2           1       2.0       218        76       203        89       230
# 3           1       2.0       218        13       203       258       119
# 4           1       2.0       218        84       172       133       192
# ..        ...       ...       ...       ...       ...       ...       ...
# 346         1       2.0       118       161       103        23       162
# 347         1       2.0       191       106       179        63       197
# 348         1       2.0       190       103       166        60       206
# 349         1       2.0       162        87       193        70       207
# 350         1       2.0       124       187       102        48       177
#
#      feature8  feature9  feature10  ...  feature25  feature26  feature27  \
# ...

# %% [markdown]
# splitting the data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
X_train
# Out:
#      feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 79          0       2.0       218       268       203         0       230
# 116         1       2.0       218        36       203       126        93
# 18          1       2.0        82       129        78       127        92
# 223         1       2.0       203       184       171       172       181
# 104         1       2.0        27        19        12        82       111
# ..        ...       ...       ...       ...       ...       ...       ...
# 71          0       2.0       218         0       203       258         0
# 106         1       2.0         9       104        12        82        17
# 270         1       2.0       218       158       185        77       212
# 348         1       2.0       190       103       166        60       206
# 102         0       2.0         9       104        12        82        17
#
#      feature8  feature9  feature10  ...  feature25  feature26  feature27  \
# ...

# %%
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size=0.5)

# %%
X_train.shape
# Out:
# (122, 34)

# %%
X_train.size
# Out:
# 4148

# %%
X_val.shape
# Out:
# (123, 34)

# %%
X_test.shape
# Out:
# (106, 34)

# %%
# Data Normalization
mean = X_train.mean(axis=0)
std = X_train.std(axis=0)

X_train -= mean
X_train /= std

X_test -= mean
X_test /= std


X_val -= mean
X_val /= std

# %%
X_train.head()
# Out:
#      feature1  feature2  feature3  feature4  feature5  feature6  feature7  \
# 47   0.343931       NaN  0.699412 -0.392697 -1.507527  0.761649 -1.515027
# 96   0.343931       NaN  0.352297  1.009282 -0.025049  0.952477  0.008835
# 268  0.343931       NaN  1.096114  0.779648 -0.363158 -1.075068  0.293785
# 235  0.343931       NaN -0.304741 -0.682761  1.132324 -1.349383  1.297304
# 220 -2.883728       NaN  1.096114 -1.383751 -1.507527  1.620374 -1.552195
#
#      feature8  feature9  feature10  ...  feature25  feature26  feature27  \
# 47   0.948679 -0.082074  -1.503721  ...   0.677212  -1.139743  -0.399197
# 96   1.141256 -0.380972   1.237531  ...  -1.482106   1.154434  -1.789372
# 268  0.435140 -0.019804  -0.219531  ...  -0.084900   1.142485  -0.468132
# 235 -1.452116  0.254186   0.187952  ...   0.307703  -0.817124   0.772686
# 220  1.808857  1.275420   1.768494  ...   1.312306   0.210476   1.105868
#
#      feature28  feature29  feature30  feature31  feature32  feature33  \
# ...

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dropout
from keras.layers import Dense
from tensorflow.keras import layers
from keras import regularizers
from sklearn import metrics

# %% [markdown]
# developing model###

# %%
model = Sequential()
model.add(Dense(16 , activation='relu', input_shape=(X_train.shape[-1],))) # Input Layer
model.add(Dense(1, activation='sigmoid')) #As this is a binary classification problem we will use sigmoid activation in the last layer.

# %% [markdown]
# Compiling Model###

# %%
optimizer = tf.keras.optimizers.Adam(learning_rate=0.001) #optimizer

model.compile(optimizer=optimizer, loss=tf.keras.losses.BinaryCrossentropy(), metrics=['accuracy']) 
#As this is a binary classification problem we will use Binary Cross Entropy for loss and Accuracy for metric.

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_2 (Dense)              (None, 16)                560
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# ...
# Total params: 577
# Trainable params: 577
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# training the model###

# %%
num_epochs = 100
history = model.fit(X_train,Y_train,epochs=num_epochs, batch_size=5, validation_split=0.5, verbose=0)
history_dict = history.history

# %%
loss_values = history_dict['loss']
val_loss_values=history_dict['val_loss']
plt.plot(loss_values,'b',label='training loss')
plt.plot(val_loss_values,'r',label='val training loss')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')

# %%
accuracy_values = history_dict['accuracy']
val_accuracy_values=history_dict['val_accuracy']
plt.plot(val_accuracy_values,'-r',label='val_accuracy')
plt.plot(accuracy_values,'-b',label='accuracy')
plt.legend()
plt.xlabel("Epochs")
# Out:
# Text(0.5, 0, 'Epochs')
